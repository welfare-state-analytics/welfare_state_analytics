# %%
import pandas as pd

df = pd.read_csv('./westac/case_study_political_in_newspapers/data/year+newspaper+text_2019-10-16.txt', sep='\t')
# Out:
#   File "<ipython-input-4-322830014a24>", line 4
#     df['tokens] = len(df.txt.str.split())
#                                          ^
# SyntaxError: EOL while scanning string literal

# %%
df['tokens'] = df.apply(lambda x: len(str(x['txt']).split()), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-83dbdc3066b4> in <module>
# ----> 1 df['tokens'] = df.apply(lambda x: len(x['txt'].split()), axis=1)
#
# ~\.virtualenvs\welfare_state_analytics-POMk69ZR\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\.virtualenvs\welfare_state_analytics-POMk69ZR\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\.virtualenvs\welfare_state_analytics-POMk69ZR\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
# ...

# %%
df.groupby(['year']).sum().plot()

# %%
df.head()
# Out:
#    year    newspaper                                                txt  \
# 0  1945  AFTONBLADET    " " bomba varje stort industriellt politiskt...
# 1  1945  AFTONBLADET    " " försökfer klarlägga åtminstone ett polit...
# 2  1945  AFTONBLADET            " " inga politiska våldsbrott gudskelov
# 3  1945  AFTONBLADET    " " krigsbrottslingama tona bort de politisk...
# 4  1945  AFTONBLADET    " " politisk explosion befaras i mystiken st...
#
#    tokens
# 0  932377
# 1  932377
# 2  932377
# 3  932377
# 4  932377
